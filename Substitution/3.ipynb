# %%
S = SubstitutionCryptosystem(AlphabeticStrings())
cipher_text = 'ABCDC EF  CGCD W HIWJ BKJCGCD EL ABC MCFA IWEX KH BNOWL PIWLF WLX ABC ONDXCDCDF KH QKBL KPCLFBWJ JCDC LCGCD AK DCRCEGI ABC KDWLSC PEPF JBERB IKLC FAWD'

print 'The Encoded Message:'
print cipher_text
encoded_y = S.encoding(cipher_text)
freq_dist = encoded_y.frequency_distribution().function()
sorted_fd = sorted(freq_dist.items(), key = lambda z: -z[1])

print 'Letter \tFrequency \t\tOccurences'
for i in sorted_fd:
    print i[0],'\t',i[1],'\t',i[1]*len(encoded_y)

def change_letter(phrase,old_letter,new_letter):
    for letter in phrase:
        if letter == old_letter:
            phrase = phrase.replace(letter,new_letter)
    return phrase

def known_letters(phrase):
    for letter in phrase:
        if (ord(letter) <= 96 and ord(letter) != 32):
            phrase = phrase.replace(letter,'-')
    return phrase

n = 0
updated_phrase = [cipher_text]
print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'C','e'))
n+=1



print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'A','t'))
n+=1
print 'Step:', n , 'Set: A = t'
print known_letters(updated_phrase[n])

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'B','h'))
n+=1
print 'Step:', n , 'Set: B = h'
print known_letters(updated_phrase[n])

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'W','a'))
n+=1
print 'Step:', n , 'Set: W = a'
print known_letters(updated_phrase[n])

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'D','r'))
n+=1
print 'Step:', n , 'Set: D = r'
print known_letters(updated_phrase[n])

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'G','v'))
n+=1
print 'Step:', n , 'Set: G = v'
print known_letters(updated_phrase[n])

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'K','o'))
n+=1
print 'Step:', n , 'Set: K = o'
print known_letters(updated_phrase[n])

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'J','w'))
n+=1
print 'Step:', n , 'Set: J = w'
print known_letters(updated_phrase[n])

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'E','i'))
n+=1
print 'Step:', n , 'Set: E = i'
print known_letters(updated_phrase[n])

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'L','n'))
n+=1
print 'Step:', n , 'Set: L = n'
print known_letters(updated_phrase[n])

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'N','u'))
n+=1
print 'Step:', n , 'Set: N = u'
print known_letters(updated_phrase[n])

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'O','m'))
n+=1
print 'Step:', n , 'Set: O = m'
print known_letters(updated_phrase[n])

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'F','s'))
n+=1
print 'Step:', n , 'Set: F = s'
print known_letters(updated_phrase[n])

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'I','l'))
n+=1
print 'Step:', n , 'Set: I = l'
print known_letters(updated_phrase[n])
