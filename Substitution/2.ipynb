# %%
S = SubstitutionCryptosystem(AlphabeticStrings())
cipher_text = 'LGGK VHZXJ RP VJJCEVO CK ZMX MGEXO C SCLDGEXJXS LGRX IVIXJL CK ZMX IGDQXZ GH ZMX SJXLL UMCDM C MVS ZVQXK HJGR PGBJ OVWGJVZGJP. VZ HCJLZ C MVS KXNOXDZXS ZMXR, WBZ KGU ZMVZ C UVL VWOX ZG SXDCIMXJ ZMX DMVJVDZXJL CK UMCDM ZMXP UXJX UJCZZXK, C WXNVK ZG LZBSP ZMXR UCZM SCOCNXKDX'

print 'The Encoded Message:'
print cipher_text
encoded_y = S.encoding(cipher_text)
freq_dist = encoded_y.frequency_distribution().function()
sorted_fd = sorted(freq_dist.items(), key = lambda z: -z[1])

print 'Letter \tFrequency \t\tOccurences'
for i in sorted_fd:
    print i[0],'\t',i[1],'\t',i[1]*len(encoded_y)

def change_letter(phrase,old_letter,new_letter):
    for letter in phrase:
        if letter == old_letter:
            phrase = phrase.replace(letter,new_letter)
    return phrase

def known_letters(phrase):
    for letter in phrase:
        if (ord(letter) <= 96 and ord(letter) != 32):
            phrase = phrase.replace(letter,'-')
    return phrase

n = 0
updated_phrase = [cipher_text]
print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'V','a'))
n+=1



print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'M','h'))
n+=1
print 'Step:', n , 'Set: M = h'
print known_letters(updated_phrase[n])

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'Z','t'))
n+=1
print 'Step:', n , 'Set: Z = t'
print known_letters(updated_phrase[n])


print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'X','e'))
n+=1
print 'Step:', n , 'Set: X = e'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'R','m'))
n+=1
print 'Step:', n , 'Set: R = n'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'G','o'))
n+=1
print 'Step:', n , 'Set: G = o'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'E','v'))
n+=1
print 'Step:', n , 'Set: E = s'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'S','d'))
n+=1
print 'Step:', n , 'Set: S = d'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'H','f'))
n+=1
print 'Step:', n , 'Set: H = f'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'J','r'))
n+=1
print 'Step:', n , 'Set: J = r'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'C','i'))
n+=1
print 'Step:', n , 'Set: C = i'
print known_letters(updated_phrase[n])
print updated_phrase[n]


print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'U','w'))
n+=1
print 'Step:', n , 'Set: U = w'
print known_letters(updated_phrase[n])
print updated_phrase[n]


print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'D','c'))
n+=1
print 'Step:', n , 'Set: D = c'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'L','s'))
n+=1
print 'Step:', n , 'Set: L = s'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'O','l'))
n+=1
print 'Step:', n , 'Set: O = l'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'N','g'))
n+=1
print 'Step:', n , 'Set: N = g'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'W','b'))
n+=1
print 'Step:', n , 'Set: W = b'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'P','y'))
n+=1
print 'Step:', n , 'Set: P = y'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'K','n'))
n+=1
print 'Step:', n , 'Set: K = n'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'Q','k'))
n+=1
print 'Step:', n , 'Set: Q = k'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'I','p'))
n+=1
print 'Step:', n , 'Set: I = p'
print known_letters(updated_phrase[n])
print updated_phrase[n]

print updated_phrase[n]
updated_phrase.append(change_letter(updated_phrase[n],'B','u'))
n+=1
print 'Step:', n , 'Set: B = u'
print known_letters(updated_phrase[n])
print updated_phrase[n]

# %%
# finished
